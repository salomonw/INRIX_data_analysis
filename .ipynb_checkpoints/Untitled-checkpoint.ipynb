# %%
# libraries
import os 
os.chdir('G:/My Drive/Github/INRIX_vis/main')

execfile('parameters.py')

import fiona
import networkx as nx
import itertools 
import osmnx as ox
import random
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, MultiPoint
import geopandas
import numpy as np
import pandas as pd
import mplleaflet

# %%
# functions
def closest_node(G, coord):
    x = coord[0]
    y = coord[0]
    closest_n = {}
    closest_n['dist'] = np.infty
    closest_n['node'] = np.nan
    pos = nx.get_node_attributes(G,'pos')
    
    for node in pos:
        X = node[0]
        Y = node[0]
        dist = (X-x)**2 + (Y-y)**2
        if dist < closest_n['dist']:
            closest_n['dist'] = dist
            closest_n['node'] = node
            
    return closest_n

# %%
# Reading the shapefles 
ShpFile = 'G:/My Drive/Github/INRIX_vis/results/comparison_2012_2015/cong_comparison_AM.shp'
G = nx.read_shp(ShpFile, geom_attrs=True)
#G_gdf = geopandas.read_file(ShpFile)
zipG = geopandas.read_file('G:/My Drive/Github/INRIX_vis/results/comparison_2012_2015/zip_comparison_AM.shp')


# Finding the centroid of each zip code
zipG['centroid'] = zipG.geometry.centroid

# reading the weigths for the 2012 and 2015 grapgs
G_2012 = nx.Graph()
G_2015 = nx.Graph()
for data in G.edges(data=True):
   G_2012.add_edge(data[0],data[1], weight=data[2]['tT_2012'], pos=data[0])
   G_2015.add_edge(data[0],data[1], weight=data[2]['tT_2015'], pos=data[0])

# getting the position of each node
for data in G.nodes(data=True):
    G_2012.node[data[0]]['pos'] = data[0]
    G_2015.node[data[0]]['pos'] = data[0]
    
# Find the closest node to the centroid of each zip code
zip_nodes = {}
zip_centroids = {}
len_nodes = len(zipG['centroid'])
cnt = 0
for index, zip_ in zipG.iterrows():
    zip_name = zip_['Zip']
    i = zip_['centroid']
    orgn_node_ = (i.x, i.y)
    zip_centroids[zip_name] = orgn_node_
    orig_node = closest_node(G_2012, orgn_node_)
    zip_nodes[zip_name] = orig_node['node']
    cnt +=1
    print('processed centroid: ' + str(cnt) + ' out of: ' + str(len_nodes))


plt.scatter(*zip(*zip_centroids.values()))
plt.scatter(*zip(*zip_nodes.values()))

print ('----------------------------------')
# Out:
# processed centroid: 1 out of: 506
# processed centroid: 2 out of: 506
# processed centroid: 3 out of: 506
# processed centroid: 4 out of: 506
# processed centroid: 5 out of: 506
# processed centroid: 6 out of: 506
# processed centroid: 7 out of: 506
# processed centroid: 8 out of: 506
# processed centroid: 9 out of: 506
# processed centroid: 10 out of: 506
# processed centroid: 11 out of: 506
# processed centroid: 12 out of: 506
# processed centroid: 13 out of: 506
# processed centroid: 14 out of: 506
# processed centroid: 15 out of: 506
# processed centroid: 16 out of: 506
# processed centroid: 17 out of: 506
# processed centroid: 18 out of: 506
# processed centroid: 19 out of: 506
# processed centroid: 20 out of: 506
# processed centroid: 21 out of: 506
# processed centroid: 22 out of: 506
# processed centroid: 23 out of: 506
# processed centroid: 24 out of: 506
# processed centroid: 25 out of: 506
# processed centroid: 498 out of: 506
# processed centroid: 499 out of: 506
# processed centroid: 500 out of: 506
# processed centroid: 501 out of: 506
# processed centroid: 502 out of: 506
# processed centroid: 503 out of: 506
# processed centroid: 504 out of: 506
# processed centroid: 505 out of: 506
# processed centroid: 506 out of: 506
# ----------------------------------

# %%
zip_nodes = {v:zip_nodes[v] for v in [list(zip_nodes.keys())[k] for k in range(50,55)]}
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-48ce72633de9> in <module>()
# ----> 1 zip_nodes = {v:zip_nodes[v] for v in [list(zip_nodes.keys())[k] for k in range(50,55)]}
#
# IndexError: list index out of range

# %%
# Calculate shortest paths. This probably can be imporved my using multi-source shortest path algorithy
n_iter = len(zip_nodes)*len(zip_nodes)
routes = {}
cnt = 0
for i in zip_nodes:
    routes[i] = {}
    zip_len2 = {}
    zip_len5 = {}
    for j in zip_nodes:
        path = {}
        cnt += 1
        path['source'] = zip_nodes[i]
        path['target'] =  zip_nodes[j]
        path['zip_source'] =  i
        path['zip_target'] =  j
        try:
            path['path_2012'] = nx.shortest_path(G_2012, zip_nodes[i], zip_nodes[j], weight='weight')
            path['length_2012'] = nx.shortest_path_length(G_2012, zip_nodes[i], zip_nodes[j], weight='weight')
            path['path_2015'] = nx.shortest_path(G_2015, zip_nodes[i], zip_nodes[j], weight='weight')
            path['length_2015'] = nx.shortest_path_length(G_2015, zip_nodes[i], zip_nodes[j], weight='weight')
        except:
            path['path_2012'] = np.infty
            path['length_2012'] = np.infty
            path['path_2015'] = np.infty
            path['length_2015'] = np.infty
        
        routes[i][j] = path
        zip_len2[j] = path['length_2012']
        zip_len5[j] = path['length_2015']
        print('processed: ' + str(cnt) + ' out of: ' + str(n_iter))
        
    gpd = zipG[['Zip', 'City', 'County', 'geometry', 'centroid' ]]
    gpd['travel_time_2012'] = gpd['Zip'].map(zip_len2)
    gpd['travel_time_2015'] = gpd['Zip'].map(zip_len5)
    
    
    #f, ax = plt.subplots(1)
    ax = gpd.plot(column='travel_time_2012', cmap='Blues',alpha=0.8)
    #mplleaflet.display(fig=ax.figure, crs=gpd.crs, tiles='cartodb_positron')
    mplleaflet.display(fig=ax, crs=gpd.crs)
    #mplleaflet.show()
# Out:
# processed: 1 out of: 25
# processed: 2 out of: 25
# processed: 3 out of: 25
# processed: 4 out of: 25
# processed: 5 out of: 25
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# processed: 6 out of: 25
# processed: 7 out of: 25
# processed: 8 out of: 25
# processed: 9 out of: 25
# processed: 10 out of: 25
# processed: 11 out of: 25
# processed: 12 out of: 25
# processed: 13 out of: 25
# processed: 14 out of: 25
# processed: 15 out of: 25
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\colors.py:937: RuntimeWarning: invalid value encountered in true_divide
#   resdat /= (vmax - vmin)
# processed: 16 out of: 25
# processed: 17 out of: 25
# processed: 18 out of: 25
# processed: 19 out of: 25
# processed: 20 out of: 25
# processed: 21 out of: 25
# processed: 22 out of: 25
# processed: 23 out of: 25
# processed: 24 out of: 25
# processed: 25 out of: 25
